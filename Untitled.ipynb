# %%
pip install pandas_datareader
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#      ----------------------------------- -- 102.4/109.5 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 109.5/109.5 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import datetime
stock1 = "META"
ticker = yf.Ticker(stock1) 
df = ticker.history(start=start, end=end)
print(df)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2012-05-18 00:00:00-04:00   42.049999   45.000000   38.000000   38.230000
# 2012-05-21 00:00:00-04:00   36.529999   36.660000   33.000000   34.029999
# 2012-05-22 00:00:00-04:00   32.610001   33.590000   30.940001   31.000000
# 2012-05-23 00:00:00-04:00   31.370001   32.500000   31.360001   32.000000
# 2012-05-24 00:00:00-04:00   32.950001   33.209999   31.770000   33.029999
# ...                               ...         ...         ...         ...
# 2022-12-23 00:00:00-05:00  116.029999  118.180000  115.540001  118.040001
# 2022-12-27 00:00:00-05:00  117.930000  118.599998  116.050003  116.879997
# 2022-12-28 00:00:00-05:00  116.250000  118.150002  115.510002  115.620003
# 2022-12-29 00:00:00-05:00  116.400002  121.029999  115.769997  120.260002
# 2022-12-30 00:00:00-05:00  118.160004  120.419998  117.739998  120.339996
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
nkhil__2=5

# %%
pip install --upgrade pandas_datareader pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/10.8 MB 1.7 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/10.8 MB 5.0 MB/s eta 0:00:03
#      --- ------------------------------------ 1.0/10.8 MB 8.3 MB/s eta 0:00:02
#      -------- ------------------------------- 2.3/10.8 MB 13.3 MB/s eta 0:00:01
#      -------------- ------------------------- 4.0/10.8 MB 18.1 MB/s eta 0:00:01
#      --------------------- ------------------ 5.8/10.8 MB 23.3 MB/s eta 0:00:01
#      --------------------------- ------------ 7.4/10.8 MB 24.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 9.5/10.8 MB 28.9 MB/s eta 0:00:01
#      --------------------------------------  10.8/10.8 MB 38.5 MB/s eta 0:00:01
#      --------------------------------------- 10.8/10.8 MB 34.4 MB/s eta 0:00:00
# ...

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/69.0 kB ? eta -:--:--
#      ---------------------------------------- 69.0/69.0 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#      -------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#      ---------------------------------------- 62.6/62.6 kB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/2.9 MB 6.3 MB/s eta 0:00:01
#      ------------- -------------------------- 1.0/2.9 MB 12.9 MB/s eta 0:00:01
#      -------------------------------- ------- 2.4/2.9 MB 18.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.5/2.9 MB 14.6 MB/s eta 0:00:01
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data
import yfinance as yf

import datetime

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2022, 12, 31)

df= yf.download('AAPL', start=start, end=end)
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478998  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490199  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386965  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375158  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417541  447610800

# %%
df=df.reset_index()
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478998  493729600
# 1 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490199  601904800
# 2 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386965  552160000
# 3 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375158  477131200
# 4 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417541  447610800

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.127060
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.307236
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.339409
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  128.889572
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.207779
#
#               Volume
# Date
# 2022-12-23  63814900
# 2022-12-27  69007800
# 2022-12-28  85438400
# 2022-12-29  75703700
# 2022-12-30  77034200

# %% [markdown]
# The date column is the index for the data. we remove the index label from that column. We cannot remove the date column from the data because it is an index. It can be identified as an index because it is highlighted in the above output.

# %%
df=df.reset_index()
df.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.478998  493729600
# 1 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.490199  601904800
# 2 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.386965  552160000
# 3 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.375158  477131200
# 4 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.417541  447610800

# %%
df=df.drop(['Date','Adj Close'],axis=1)

# %% [markdown]
# The columns Date and Adj Close	are not needed and they are removed.

# %%
df.head()
# Out:
#        Open      High       Low     Close     Volume
# 0  7.622500  7.660714  7.585000  7.643214  493729600
# 1  7.664286  7.699643  7.616071  7.656429  601904800
# 2  7.656429  7.686786  7.526786  7.534643  552160000
# 3  7.562500  7.571429  7.466071  7.520714  477131200
# 4  7.510714  7.571429  7.466429  7.570714  447610800

# %% [markdown]
# This plot means for the column Close out of the 3271 values what are the values of Close.

# %%
plt.plot(df.Close)

# %%
Rolling average . Average is shown after 100 values.

# %%
ma100 = df. Close.rolling(100).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3267    150.515600
# 3268    150.157800
# 3269    149.764699
# 3270    149.412100
# 3271    149.062199
# Name: Close, Length: 3272, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,"r")

# %%
ma200 = df. Close.rolling(200).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 3267    150.515600
# 3268    150.157800
# 3269    149.764699
# 3270    149.412100
# 3271    149.062199
# Name: Close, Length: 3272, dtype: float64

# %% [markdown]
# read about exponential and rolling average in the internet

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100,"r")
plt.plot(ma200,"g")

# %%
# unwanted
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (3272, 5)

# %%
#unwanted experimenting in this cell
df1=df['Close']
df1.shape
# Out:
# (3272,)

# %%
#split data into trainning and testing.
# 
data_training =pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

# %%
print(data_training.shape)
print(data_testing.shape)
# Out:
# (2290, 1)
# (982, 1)

# %% [markdown]
# For the stacked lstm model we need to scale the data using Min Max of range0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler(feature_range=(0,1))

# %%
data_training_array= scaler.fit_transform(data_training)

# %%
data_testing_array=scaler.fit_transform(data_testing)

# %%
print(data_training_array[1])
# Out:
# [0.01558878]

# %%
x_train=[]
y_train=[]

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

# %%
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (2190, 100, 1)

# %%
y_train.shape
# Out:
# (2190,)

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model= Sequential()
model.add(LSTM(units=50,activation ='relu',return_sequences =True, input_shape =(x_train.shape[1],1)))
model. add(Dropout(0.2))


model.add(LSTM(units=60,activation ='relu',return_sequences =True))
model. add(Dropout(0.3))

model.add(LSTM(units=80,activation ='relu',return_sequences =True))
model. add(Dropout(0.4))

model.add(LSTM(units=120,activation ='relu'))
model. add(Dropout(0.5))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_5 (LSTM)               (None, 100, 50)           10400
#
#  dropout_3 (Dropout)         (None, 100, 50)           0
#
#  lstm_6 (LSTM)               (None, 100, 60)           26640
#
#  dropout_4 (Dropout)         (None, 100, 60)           0
#
#  lstm_7 (LSTM)               (None, 100, 80)           45120
#
#  dropout_5 (Dropout)         (None, 100, 80)           0
#
#  lstm_8 (LSTM)               (None, 120)               96480
#
#  dropout_6 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 1)                 121
#
# ...
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# Epoch 1/50
# 69/69 [==============================] - 26s 273ms/step - loss: 0.0303
# Epoch 2/50
# 69/69 [==============================] - 19s 269ms/step - loss: 0.0060
# Epoch 3/50
# 69/69 [==============================] - 19s 278ms/step - loss: 0.0057
# Epoch 4/50
# 69/69 [==============================] - 20s 286ms/step - loss: 0.0057
# Epoch 5/50
# 69/69 [==============================] - 24s 342ms/step - loss: 0.0044
# Epoch 6/50
# 69/69 [==============================] - 24s 348ms/step - loss: 0.0045
# Epoch 7/50
# 69/69 [==============================] - 18s 261ms/step - loss: 0.0042
# Epoch 8/50
# 69/69 [==============================] - 24s 343ms/step - loss: 0.0049
# Epoch 9/50
# 69/69 [==============================] - 22s 314ms/step - loss: 0.0036
# Epoch 10/50
# 69/69 [==============================] - 21s 304ms/step - loss: 0.0036
# Epoch 11/50
# 69/69 [==============================] - 20s 284ms/step - loss: 0.0034
# Epoch 12/50
# ...

# %%
model.save('keras_model.h5')

# %%
# The index name is from the first list, you can ignore the index it is shown in the next append statement below.

data_testing
# Out:
#            Close
# 2290   42.602501
# 2291   42.357498
# 2292   42.722500
# 2293   42.544998
# 2294   42.700001
# ...          ...
# 3267  131.860001
# 3268  130.029999
# 3269  126.040001
# 3270  129.610001
# 3271  129.929993
#
# [982 rows x 1 columns]

# %%
past_100_days= data_training.tail(100)

# %%
final_df =past_100_days.append(data_testing, ignore_index= True)
# Out:
# C:\Users\91944\AppData\Local\Temp\ipykernel_540\36234194.py:1: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
final_df
# Out:
#            Close
# 0      55.959999
# 1      54.470001
# 2      54.560001
# 3      54.592499
# 4      55.007500
# ...          ...
# 1077  131.860001
# 1078  130.029999
# 1079  126.040001
# 1080  129.610001
# 1081  129.929993
#
# [1082 rows x 1 columns]

# %%
input_data= scaler.fit_transform(final_df)

# %%
x_test=[]
y_test=[]
for i in range(100,input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i,0])

# %%
x_test,y_test=np.array(x_test),np.array(y_test)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (982, 100, 1)
# (982,)

# %%
y_prediction=model.predict(x_test)
# Out:
# 31/31 [==============================] - 6s 92ms/step

# %%
y_prediction.shape
# Out:
# (982, 1)

# %%
y_test
# Out:
# array([0.04816933, 0.04649653, 0.04898865, 0.04777672, 0.04883503,
#        0.04818639, 0.04905691, 0.05093454, 0.04927882, 0.05253905,
#        0.05468976, 0.05486046, 0.05578219, 0.05284628, 0.05595289,
#        0.05745499, 0.05690876, 0.05518478, 0.05173679, 0.05243663,
#        0.06266108, 0.06609201, 0.06745755, 0.07090551, 0.07498506,
#        0.07822822, 0.0756849 , 0.07846719, 0.09029614, 0.08340019,
#        0.07945721, 0.07612869, 0.07899633, 0.07942306, 0.08152257,
#        0.08372451, 0.08846975, 0.09073996, 0.09132031, 0.09355637,
#        0.09884784, 0.09782367, 0.09973542, 0.09688486, 0.09674831,
#        0.0973628 , 0.09739694, 0.10401981, 0.10526585, 0.10640949,
#        0.1114449 , 0.1108987 , 0.10768968, 0.1060169 , 0.10654605,
#        0.09982077, 0.11663396, 0.11429546, 0.11873346, 0.11315182,
#        0.10355893, 0.1036272 , 0.09990612, 0.0938636 , 0.0743023 ,
#        0.07932065, 0.08317828, 0.08174448, 0.079901  , 0.06981308,
# ...

# %%
y_prediction
# Out:
# array([[0.10180458],
#        [0.10245207],
#        [0.10316738],
#        [0.10390812],
#        [0.10464197],
#        [0.1053433 ],
#        [0.10599616],
#        [0.1065916 ],
#        [0.10713103],
#        [0.10761966],
#        [0.10806593],
#        [0.10848743],
#        [0.10890099],
#        [0.10931963],
#        [0.10974684],
#        [0.11018156],
#        [0.11062834],
#        [0.11108822],
#        [0.11155473],
#        [0.11201152],
#        [0.11244071],
#        [0.11284965],
#        [0.11326824],
#        [0.1137251 ],
#        [0.1142461 ],
#        [0.11485645],
#        [0.11557689],
#        [0.11637674],
#        [0.1172372 ],
#        [0.11817403],
#        [0.11919492],
#        [0.1202776 ],
#        [0.12138444],
#        [0.12247789],
#        [0.12352988],
#        [0.12452331],
#        [0.1254556 ],
#        [0.1263389 ],
#        [0.12719545],
#        [0.12804654],
#        [0.12891124],
#        [0.12981206],
#        [0.1307643 ],
# ...

# %%
scaler.scale_
# Out:
# array([0.00682769])

# %%
scale_factor=1/0.0068276
y_prediction*=scale_factor
y_test*=scale_factor

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label="Original Closing Price")
plt.plot(y_prediction,'r',label="Predicted Closing Price")
plt.xlabel('time')
plt.ylabel('Price')
plt.show()
